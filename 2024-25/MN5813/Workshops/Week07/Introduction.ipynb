# %% [markdown]
# # MN5813: Data Wrangling Hackathon! (Introduction)

# %% [markdown]
# _This notebook introduces the `data wrangling hackathon` in preparation of the [group project](https://github.com/REPPL/Teaching/blob/main/2024-25/MN5813/Workshops/Week06/Introduction.ipynb)._
#
# Note: This Jupyter Notebook were originally compiled by Alex Reppel (AR).

# %% [markdown]
# ## Session aim

# %% [markdown]
# The aim of today's session is to get you started with your group project. By the end of the session, each group should have achieved the following:
#
# ### Data loading
#
# 1. Setup the template _(i.e., adapt; add your student ID numbers, etc.)_
# 2. Download the dataset as a `.csv` file
# 3. Place the `.csv` file in the same directory _(folder)_ where your Jupyter Notebook resides
# 4. Load the `.csv` file using [Pandas](https://pandas.pydata.org/)
#
# _(Do not yet attempt stretch goals. They should come later.)_
#
# ### Data cleaning
#
# 1. Use `df.head()` to explore the dataset. Do that as a team, that is, examine it together!
# 2. Discuss how to handle missing values. There are often different ways _(depending on the column)_ to do so; make sure you record your assumptions and/or reasons for your decisions!
# 3. Covert data types where necessary -- at a minimum, convert `Year` into a `datatime` object.
# 4. Remove dublicates
#
# ### Data wrangling
#
# Some groups may already begin this section, although this isn't required; if you get to complete the above steps on data cleaning, you have achieved a lot!
