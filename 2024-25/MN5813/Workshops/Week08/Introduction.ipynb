# %% [markdown]
# # MN5813: Working with R Hackathon! (Introduction)

# %% [markdown]
# _This notebook introduces another `hackathon`; this time, we'll be trying to convert Python/Pandas code we've already written into [R](https://www.r-project.org/) -- or convert R code into Python. This may (or may not) be fun!_
#
# Note: This Jupyter Notebook were originally compiled by Alex Reppel (AR).
