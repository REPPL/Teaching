# %% [markdown]
# # MN5813: Module Overview (Setup instructions)
#
# _This notebook provides materials for you to install [Anaconda](https://docs.anaconda.com/anaconda/install/) and to test your local installation._

# %% [markdown]
# ## Tutorial

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("YJC6ldI3hWk", width=560)

# %% [markdown]
# ## Official installation instructions

# %% [markdown]
# - Installing Anaconda: https://docs.anaconda.com/anaconda/install/.
# - Verifying your installation: https://docs.anaconda.com/anaconda/install/verify-install/.
