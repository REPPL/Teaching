# %% [markdown]
# # MN5813: Introduction to Data Visualisation (Demonstration)

# %% [markdown]
# _This notebook introduces basic concepts around data visualisation._
#
# Note: This Jupyter Notebook were originally compiled by Alex Reppel (AR).
