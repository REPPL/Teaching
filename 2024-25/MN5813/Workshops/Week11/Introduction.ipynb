# %% [markdown]
# # MN5813: Working with R Hackathon! (Introduction)

# %% [markdown]
# _This notebook introduces another `hackathon`; this time, we'll be trying to convert Python/Pandas code we've already written into [R](https://www.r-project.org/) -- or convert R code into Python. This may (or may not) be fun!_
#
# Note: This Jupyter Notebook were originally compiled by Alex Reppel (AR).

# %% [markdown]
# ## Session aim

# %% [markdown]
# The aim of this session is for you to experiment with generative AI to help you convert a project from one programming language into another language. This will be the first time that we try this as part of this module, which means that this is an experiment ... which may or may not work!
#
# I also recognise that some groups may not wish to participate and instead concentrate on advancing their group project. That's great, and we'll be there to support you with that.

# %% [markdown]
# ### Participate in the R to Python hackathon
#
# If you decide to participate in the R to Python `hackathon`, I suggest that you choose an R script on GitHub and use your preferred generative AI tool to convert it into Python.
#
# As always with generative AI, this may work ... or not. If it doesn't, I suggest you start with small steps, investigate the resulting Python code, and then take another step, etc. -- the purpose of the `hackathon` is for us to figure out how we may be able to use generative AI productively when moving between programming languages.
#
# If you cannot find an appropriate R script on GitHub, go to the Module Handbook and look at the resources listed for week 08. The "[Using Network Graphs and R to Visualize Stories](https://github.com/REPPL/Using-network-graphs-and-R-to-visualize-stories)" R script may be a good start. _(While the script is available on GitHub, a video tutorial can be accessed via the "Resouces" page for week 08.)_

# %% [markdown]
# ### Continue with your group project
#
# Of course, you may decide not to participate in the R to Python `hackathon` and instead continue with the group project. If that's what you decide to do, I suggest that you try to complete the remaining "Data wrangling" and "Data analysis" steps _(listed in the "Introduction" to week 06.)_
