# %% [markdown]
# # MN5813: Data Visualsation Hackathon! (Introduction)

# %% [markdown]
# _This notebook introduces the `data visualisation hackathon` for your group project._
#
# Note: This Jupyter Notebook were originally compiled by Alex Reppel (AR).
