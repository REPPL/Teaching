# %% [markdown]
# # MN5813: Introduction to Python (Demonstration)

# %% [markdown]
# _This notebook provides an introduction to basic Python concepts and syntax. It covers variables, basic operations, control structures, functions, and data structures like lists and dictionaries._
#
# Note: This Jupyter Notebook was originally written by Jialun Hu (JH); it was reformatted and expanded by Alex Reppel (AR) based on conversations with [ClaudeAI](https://claude.ai/) *(version 3.5 Sonnet)*.

# %% [markdown]
# ## Getting started ...
#
# Let's begin with some simple arithmetic operations to demonstrate how Python handles basic math.

# %%
print(2 + 3 * 4)  # Multiplication has higher precedence
print((2 + 3) * 4)  # Parentheses override default precedence
print(10 / 3)  # Division always returns a float
print(10 // 3)  # Floor division discards the fractional part
print(10 % 3)  # Modulo: returns the remainder of the division
print(2 ** 3)  # Exponentiation

# %% [markdown]
# ## Variables
#
# Variables are used to store data in Python. They can hold different types of data, such as strings _(text)_, numbers, or more complex data structures.

# %%
name = "Alice"
age = 30
height = 1.75
is_student = True

print(f"Name: {name}, Type: {type(name)}")
print(f"Age: {age}, Type: {type(age)}")
print(f"Height: {height}, Type: {type(height)}")
print(f"Is student: {is_student}, Type: {type(is_student)}")

# %%
# Variables can be reassigned
x = 5
print(f"x = {x}")

# %%
x = "five"
print(f"x = {x}")

# %%
# Multiple assignment
a, b, c = 1, 2, 3
print(f"a = {a}, b = {b}, c = {c}")

# %% [markdown]
# ## Decisions
#
# Python uses if-elif-else statements for making decisions in code. This allows the program to execute different code based on certain conditions.

# %%
def grade_student(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

# %%
# Test the function
scores = [95, 82, 75, 68, 55]
for score in scores[:2]:
    print(f"Score: {score}, Grade: {grade_student(score)}")
print("DONE")

# %%
# Ternary operator
age = 20
status = "adult" if age >= 18 else "minor"
print(f"A person aged {age} is an {status}")

# %%
# Nested if statements
num = 15
if num > 0:
    if num % 2 == 0:
        print(f"{num} is positive and even")
    else:
        print(f"{num} is positive and odd")
else:
    print(f"{num} is not positive")

# %% [markdown]
# ## Loops
#
# Loops allow you to repeat a block of code multiple times. Python has two main types of loops: 'for' loops and 'while' loops.

# %%
# For loop with range
for i in range(5):
    print(i, end=" ")
print()  # Newline

# %%
# For loop with list
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit, end=" ")
print()  # Newline

# %%
# While loop
count = 0
while count < 5:
    print(count, end=" ")
    count += 1
print()  # Newline

# %%
# Nested loops
for i in range(3):
    for j in range(3):
        print(f"({i},{j})", end=" ")
    print()  # Newline

# %% [markdown]
# ## Functions
#
# Functions are reusable blocks of code that perform a specific task. They help in organizing code and making it more modular.

# %%
def greet(name, greeting="Hello"):
    """A simple greeting function
    
    Args:
        name (str): The name of the person to greet
        greeting (str, optional): The greeting to use. Defaults to "Hello".
    
    Returns:
        str: The full greeting
    """
    return f"{greeting}, {name}!"

# %%
print(greet("Alice"))
print(greet("Bob", "Good morning"))

# %%
# Function with variable number of arguments
def sum_all(*args):
    print(args)
    return sum(args)

print(sum_all(1, 2, 3, 4, 5))

# %%
# Lambda function (anonymous function)
square = lambda x: x**2
print(square(5))

# %% [markdown]
# ## String manipulation
#
# Python provides various methods to manipulate strings, such as replacing characters, removing whitespace, and splitting strings.

# %%
s = "Hello, World!"

# %%
print(s.lower())  # Convert to lowercase
print(s.upper())  # Convert to uppercase
print(s.replace("World", "Python"))  # Replace substring
print(s.split(","))  # Split string into list

# %%
# String formatting
name = "Alice"
age = 30
print("My name is {} and I'm {} years old".format(name, age))
print(f"My name is {name} and I'm {age} years old")  # f-string (Python 3.6+)

# %%
# String methods
text = "   Python is awesome   "
print(text.strip())  # Remove leading/trailing whitespace
print(text.find("awesome"))  # Find substring index
print(",".join(["apple", "banana", "cherry"]))  # Join list into string

# %% [markdown]
# ## Playing with lists
#
# Lists are ordered collections of items in Python. They can contain different ``types`` and are ``mutable`` (that is, they can be changed after creation).

# %%
fruits = ["apple", "banana", "cherry", "date"]

# %%
print(fruits[0])  # Accessing elements
print(fruits[-1])  # Negative indexing
print(fruits[1:3])  # Slicing

# %%
fruits.append("elderberry")  # Add element to the end
fruits.insert(1, "blueberry")  # Insert element at specific index
fruits.remove("cherry")  # Remove specific element

popped = fruits.pop()  # Remove and return last element

print(f"Popped: {popped}")
print(f"Updated fruits: {fruits}")

# %%
# List comprehension (Advanced!)
squares = [x**2 for x in range(5)]
print(f"Squares: {squares}")

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

# Sorting
print(f"Sorted: {sorted(numbers)}")
print(f"Original: {numbers}")

numbers.sort()
print(f"Sorted in-place: {numbers}")

# %% [markdown]
# ## Dictionaries
#
# Dictionaries are unordered collections of ``key-value pairs``. They are useful for storing and retrieving data using ``unique`` keys.

# %%
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York",
    "hobbies": ["reading", "painting", "hiking"]
}

# %%
# print(person["job"])  # Accessing values
print(person.get("job", "Not specified"))  # Using get() with default value

# %%
person["job"] = "Engineer"  # Adding new key-value pair
person["age"] = 31  # Modifying existing value

# %%
# Iterating through dictionary
for key, value in person.items():
    print(f"{key}: {value}")

# %%
# Dictionary comprehension (Advanced!)
squares = {x: x**2 for x in range(5)}
print(f"Squares: {squares}")

# %%
# Nested dictionaries
users = {
    "alice": {"email": "alice@example.com", "age": 30},
    "bob": {"email": "bob@example.com", "age": 25}
}

print(f"Bob's email: {users["bob"]["email"]}")
